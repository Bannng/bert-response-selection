# %%
import pandas as pd

# %%
valid = pd.read_csv('./rsc/data/valid.csv')

# %%
valid
# Out:
#                                                  Context  \
# 0      Any ideas on how lts will be released ? __eou_...
# 1      how much hdd use ubuntu default install ? __eo...
# 2      in my country its nearly the 27th __eou__ when...
# 3      it's not out __eou__ __eot__ they probabaly ar...
# 4      are the ext4 drivers stable? __eou__ __eot__ I...
# ...                                                  ...
# 19555  you mean if I install xubuntu, it has a usable...
# 19556  hi all, i'm on an acer aspire x1700 that dual ...
# 19557  i am not using openjdk. but the .tar file extr...
# 19558  What's Lubuntu? __eou__ __eot__ Would this hel...
# 19559  !java __eou__ __eot__  might be best to just i...
#
#                                   Ground Truth Utterance  \
# 0                 We are talking 12.04 not 10.04 __eou__
# 1      thats why i ask how much is default install ? ...
# 2                                          thanx __eou__
# ...

# %%
valid['combined'] = valid.apply(lambda x: list(
        [x['Ground Truth Utterance'], x['Distractor_0'], x['Distractor_1'], x['Distractor_2'], x['Distractor_3'],
         x['Distractor_4'], x['Distractor_5'], x['Distractor_6'], x['Distractor_7'], x['Distractor_8']]), axis=1)

# %%
valid['combined'].values.tolist()
# Out:
# [['We are talking 12.04 not 10.04 __eou__',
#   'you remember my flash issue from yesterday or the day before? __eou__',
#   'oh, no idea other is probably ok __eou__ update-manager or even apt __eou__ it will be sorted to the right package by a bug triager, dont worry about it to much __eou__ since unity is a compiz plugin i would say everyone who uses unity does :) __eou__ as i said above, unity is a compiz plugin ... so it would be heavily noticed if compiz wouldnt work __eou__',
#   "no, greenit is saying his download speeds are slow, when connecting to a machine on his same LAN. I'm unsure why you think setting it up to go to the internet would be A) easier, and B) make it any faster __eou__ well that is probably the issue then. He needs to be at 1280x1024 instead of 1024x768 __eou__",
# ...
